# %% [markdown]
# Mahesh Someshwar Patil
#
# RBT21CB062
#
# Topic: Analysis of Time complexities of Sorting Algorithms

# %%
import plotly #used for plotting graphs
import pandas as pd
import plotly.express as px

# %%
#creating dataframe Best Case
df1=pd.DataFrame([[10,1,"Insertion"],[100,1,"Insertion"],[500,2,"Insertion"],[1000,3,"Insertion"],
                 [2500,4,"Insertion"],[5000,6,"Insertion"],[7500,8,"Insertion"],[10000,13,"Insertion"],
                 [10,1,"Selection"],[100,6,"Selection"],[500,122,"Selection"],[1000,350,"Selection"],
                 [2500,2038,"Selection"],[5000,10288,"Selection"],[7500,19766,"Selection"],[10000,34465,"Selection"],
                 [10,1,"Quick"],[100,8,"Quick"],[500,121,"Quick"],[1000,451,"Quick"],
                 [2500,1941,"Quick"],[5000,9597,"Quick"],[7500,18402,"Quick"],[10000,30486,"Quick"],
                  [10,1,"Merge"],[100,6,"Merge"],[500,14,"Merge"],[1000,30,"Merge"],
                 [2500,82,"Merge"],[5000,153,"Merge"],[7500,253,"Merge"],[10000,319,"Merge"]],
                columns=["Range","Time","Sorting"])
df1.head(20)
# Out:
#     Range   Time    Sorting
# 0      10      1  Insertion
# 1     100      1  Insertion
# 2     500      2  Insertion
# 3    1000      3  Insertion
# 4    2500      4  Insertion
# 5    5000      6  Insertion
# 6    7500      8  Insertion
# 7   10000     13  Insertion
# 8      10      1  Selection
# 9     100      6  Selection
# 10    500    122  Selection
# 11   1000    350  Selection
# 12   2500   2038  Selection
# 13   5000  10288  Selection
# 14   7500  19766  Selection
# 15  10000  34465  Selection
# 16     10      1      Quick
# 17    100      8      Quick
# 18    500    121      Quick
# 19   1000    451      Quick

# %%
#Creating dataframe for Average Case
df2=pd.DataFrame([[10,1,"Insertion"],[100,7,"Insertion"],[500,87,"Insertion"],[1000,357,"Insertion"],
                 [2500,1280,"Insertion"],[5000,4769,"Insertion"],[7500,15916,"Insertion"],[10000,34635,"Insertion"],
                 [10,1,"Selection"],[100,8,"Selection"],[500,126,"Selection"],[1000,450,"Selection"],
                 [2500,2105,"Selection"],[5000,10737,"Selection"],[7500,21637,"Selection"],[10000,44803,"Selection"],
                 [10,1,"Quick"],[100,5,"Quick"],[500,38,"Quick"],[1000,52,"Quick"],
                 [2500,131,"Quick"],[5000,332,"Quick"],[7500,569,"Quick"],[10000,765,"Quick"],
                 [10,1,"Merge"],[100,8,"Merge"],[500,40,"Merge"],[1000,82,"Merge"],
                 [2500,196,"Merge"],[5000,422,"Merge"],[7500,653,"Merge"],[10000,871,"Merge"]],
                columns=["Range","Time","Sorting"])
df2.head(20)
# Out:
#     Range   Time    Sorting
# 0      10      1  Insertion
# 1     100      7  Insertion
# 2     500     87  Insertion
# 3    1000    357  Insertion
# 4    2500   1280  Insertion
# 5    5000   4769  Insertion
# 6    7500  15916  Insertion
# 7   10000  34635  Insertion
# 8      10      1  Selection
# 9     100      8  Selection
# 10    500    126  Selection
# 11   1000    450  Selection
# 12   2500   2105  Selection
# 13   5000  10737  Selection
# 14   7500  21637  Selection
# 15  10000  44803  Selection
# 16     10      1      Quick
# 17    100      5      Quick
# 18    500     38      Quick
# 19   1000     52      Quick

# %%
#Creating dataframe for Worst Case
df3=pd.DataFrame([[10,1,"Insertion"],[100,8,"Insertion"],[500,113,"Insertion"],[1000,437,"Insertion"],
                 [2500,2284,"Insertion"],[5000,8430,"Insertion"],[7500,19182,"Insertion"],[10000,48668,"Insertion"],
                 [10,1,"Selection"],[100,10,"Selection"],[500,131,"Selection"],[1000,466,"Selection"],
                 [2500,2290,"Selection"],[5000,9677,"Selection"],[7500,20925,"Selection"],[10000,50787,"Selection"],
                 [10,1,"Quick"],[100,7,"Quick"],[500,92,"Quick"],[1000,396,"Quick"],
                 [2500,1804,"Quick"],[5000,5799,"Quick"],[7500,13768,"Quick"],[10000,24788,"Quick"],
                 [10,1,"Merge"],[100,7,"Merge"],[500,28,"Merge"],[1000,34,"Merge"],
                 [2500,89,"Merge"],[5000,186,"Merge"],[7500,272,"Merge"],[10000,389,"Merge"]],
                columns=["Range","Time","Sorting"])
df3.head(20)
# Out:
#     Range   Time    Sorting
# 0      10      1  Insertion
# 1     100      8  Insertion
# 2     500    113  Insertion
# 3    1000    437  Insertion
# 4    2500   2284  Insertion
# 5    5000   8430  Insertion
# 6    7500  19182  Insertion
# 7   10000  48668  Insertion
# 8      10      1  Selection
# 9     100     10  Selection
# 10    500    131  Selection
# 11   1000    466  Selection
# 12   2500   2290  Selection
# 13   5000   9677  Selection
# 14   7500  20925  Selection
# 15  10000  50787  Selection
# 16     10      1      Quick
# 17    100      7      Quick
# 18    500     92      Quick
# 19   1000    396      Quick

# %%
fig1=px.line(df1,x="Range",y="Time",#template="plotly_dark", 
             width=900,height=800,
            labels={"Time":"Time (in μSec)","Range":"Input Range"},markers=True,text="Time",color="Sorting")
fig1.update_traces(textposition="top center")
fig1.update_traces(marker_size=10)
fig1.update_layout(title_text="Time across Range and Sorting Techniques (Best Case)",title_x=0.5)
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0d6c3fe0-0e9e-4300-8800-053d63594ab5" class="plotly-graph-div" style="height:800px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d6c3fe0-0e9e-4300-8800-053d63594ab5")) {                    Plotly.newPlot(                        "0d6c3fe0-0e9e-4300-8800-053d63594ab5",                        [{"hovertemplate":"Sorting=Insertion<br>Input Range=%{x}<br>Time (in \u03bcSec)=%{text}<extra></extra>","legendgroup":"Insertion","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"markers+lines+text","name":"Insertion","orientation":"v","showlegend":true,"text":[1.0,1.0,2.0,3.0,4.0,6.0,8.0,13.0],"x":[10,100,500,1000,2500,5000,7500,10000],"xaxis":"x","y":[1,1,2,3,4,6,8,13],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Sorting=Selection<br>Input Range=%{x}<br>Time (in \u03bcSec)=%{text}<extra></extra>","legendgroup":"Selection","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"markers+lines+text","name":"Selection","orientation":"v","showlegend":true,"text":[1.0,6.0,122.0,350.0,2038.0,10288.0,19766.0,34465.0],"x":[10,100,500,1000,2500,5000,7500,10000],"xaxis":"x","y":[1,6,122,350,2038,10288,19766,34465],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Sorting=Quick<br>Input Range=%{x}<br>Time (in \u03bcSec)=%{text}<extra></extra>","legendgroup":"Quick","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"markers+lines+text","name":"Quick","orientation":"v","showlegend":true,"text":[1.0,8.0,121.0,451.0,1941.0,9597.0,18402.0,30486.0],"x":[10,100,500,1000,2500,5000,7500,10000],"xaxis":"x","y":[1,8,121,451,1941,9597,18402,30486],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Sorting=Merge<br>Input Range=%{x}<br>Time (in \u03bcSec)=%{text}<extra></extra>","legendgroup":"Merge","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"markers+lines+text","name":"Merge","orientation":"v","showlegend":true,"text":[1.0,6.0,14.0,30.0,82.0,153.0,253.0,319.0],"x":[10,100,500,1000,2500,5000,7500,10000],"xaxis":"x","y":[1,6,14,30,82,153,253,319],"yaxis":"y","type":"scatter","textposition":"top center"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888 ...

# %% [markdown]
# **Observation:**
#
# In Best case that is when all the elements are arranged in increasing order ,
#
# Performance of Sorting alorithms are as follows -->
#
# Insertion < Merge < Quick < selection  (Increasing Time complexity)

# %%
fig2=px.line(df2,x="Range",y="Time",width=650,height=500,
            labels={"Time":"Time (in μSec)","Range":"Input Range"},markers=True,text="Time",color="Sorting")
fig2.update_traces(textposition="top center")
fig2.update_traces(marker_size=10)
fig2.update_layout(title_text="Time across Range and Sorting Techniques (Average Case)",title_x=0.5)
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="059382b2-050e-46f9-b829-b49595bda8b2" class="plotly-graph-div" style="height:500px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("059382b2-050e-46f9-b829-b49595bda8b2")) {                    Plotly.newPlot(                        "059382b2-050e-46f9-b829-b49595bda8b2",                        [{"hovertemplate":"Sorting=Insertion<br>Input Range=%{x}<br>Time (in \u03bcSec)=%{text}<extra></extra>","legendgroup":"Insertion","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"markers+lines+text","name":"Insertion","orientation":"v","showlegend":true,"text":[1.0,7.0,87.0,357.0,1280.0,4769.0,15916.0,34635.0],"x":[10,100,500,1000,2500,5000,7500,10000],"xaxis":"x","y":[1,7,87,357,1280,4769,15916,34635],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Sorting=Selection<br>Input Range=%{x}<br>Time (in \u03bcSec)=%{text}<extra></extra>","legendgroup":"Selection","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"markers+lines+text","name":"Selection","orientation":"v","showlegend":true,"text":[1.0,8.0,126.0,450.0,2105.0,10737.0,21637.0,44803.0],"x":[10,100,500,1000,2500,5000,7500,10000],"xaxis":"x","y":[1,8,126,450,2105,10737,21637,44803],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Sorting=Quick<br>Input Range=%{x}<br>Time (in \u03bcSec)=%{text}<extra></extra>","legendgroup":"Quick","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"markers+lines+text","name":"Quick","orientation":"v","showlegend":true,"text":[1.0,5.0,38.0,52.0,131.0,332.0,569.0,765.0],"x":[10,100,500,1000,2500,5000,7500,10000],"xaxis":"x","y":[1,5,38,52,131,332,569,765],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Sorting=Merge<br>Input Range=%{x}<br>Time (in \u03bcSec)=%{text}<extra></extra>","legendgroup":"Merge","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"markers+lines+text","name":"Merge","orientation":"v","showlegend":true,"text":[1.0,8.0,40.0,82.0,196.0,422.0,653.0,871.0],"x":[10,100,500,1000,2500,5000,7500,10000],"xaxis":"x","y":[1,8,40,82,196,422,653,871],"yaxis":"y","type":"scatter","textposition":"top center"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a" ...

# %% [markdown]
# **Observation:** (Average Case)
#
# In Average case that is when all the elements are arranged in random order ,
#
# Performance of Sorting alorithms are as follows -->
#
#
#  Quick < Merge < Insertion < Selection
#
# nlogn      nlogn         n^2            n^2
#
#
# **Observation:** (Worst Case)
#
# In Worst case that is when all the elements are arranged in random order ,
#
# Performance of Sorting alorithms are as follows -->
#
#
#  Merge < Quick < Insertion < Selection

# %%
fig3=px.line(df3,x="Range",y="Time",#template="plotly_dark",
             width=650,height=500,
            labels={"Time":"Time (in μSec)","Range":"Input Range"},markers=True,text="Time",color="Sorting")
fig3.update_traces(textposition="top center")
fig3.update_traces(marker_size=10)
fig3.update_layout(title_text="Time across Range and Sorting Techniques (Worst Case)",title_x=0.5)
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="486ef2b0-a08a-4920-9935-5ff29c7a67cf" class="plotly-graph-div" style="height:500px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("486ef2b0-a08a-4920-9935-5ff29c7a67cf")) {                    Plotly.newPlot(                        "486ef2b0-a08a-4920-9935-5ff29c7a67cf",                        [{"hovertemplate":"Sorting=Insertion<br>Input Range=%{x}<br>Time (in \u03bcSec)=%{text}<extra></extra>","legendgroup":"Insertion","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"markers+lines+text","name":"Insertion","orientation":"v","showlegend":true,"text":[1.0,8.0,113.0,437.0,2284.0,8430.0,19182.0,48668.0],"x":[10,100,500,1000,2500,5000,7500,10000],"xaxis":"x","y":[1,8,113,437,2284,8430,19182,48668],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Sorting=Selection<br>Input Range=%{x}<br>Time (in \u03bcSec)=%{text}<extra></extra>","legendgroup":"Selection","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"markers+lines+text","name":"Selection","orientation":"v","showlegend":true,"text":[1.0,10.0,131.0,466.0,2290.0,9677.0,20925.0,50787.0],"x":[10,100,500,1000,2500,5000,7500,10000],"xaxis":"x","y":[1,10,131,466,2290,9677,20925,50787],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Sorting=Quick<br>Input Range=%{x}<br>Time (in \u03bcSec)=%{text}<extra></extra>","legendgroup":"Quick","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"markers+lines+text","name":"Quick","orientation":"v","showlegend":true,"text":[1.0,7.0,92.0,396.0,1804.0,5799.0,13768.0,24788.0],"x":[10,100,500,1000,2500,5000,7500,10000],"xaxis":"x","y":[1,7,92,396,1804,5799,13768,24788],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Sorting=Merge<br>Input Range=%{x}<br>Time (in \u03bcSec)=%{text}<extra></extra>","legendgroup":"Merge","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"markers+lines+text","name":"Merge","orientation":"v","showlegend":true,"text":[1.0,7.0,28.0,34.0,89.0,186.0,272.0,389.0],"x":[10,100,500,1000,2500,5000,7500,10000],"xaxis":"x","y":[1,7,28,34,89,186,272,389],"yaxis":"y","type":"scatter","textposition":"top center"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777777777777 ...
